# %%
from dotenv import load_dotenv
import os
import requests
import json
import pymongo
from pymongo import UpdateOne
import pandas as pd

# %%
load_dotenv()
client = pymongo.MongoClient(os.getenv("MONGODB_URI"))

# %%
df = pd.read_csv("gutenberg.csv")

# %%
df
# Out:
#        Text#  Type      Issued  \
# 0          1  Text  1971-12-01
# 1          2  Text  1972-12-01
# 2          3  Text  1973-11-01
# 3          4  Text  1973-11-01
# 4          5  Text  1975-12-01
# ...      ...   ...         ...
# 74289  74455  Text  2024-09-21
# 74290  74456  Text  2024-09-21
# 74291  74457  Text  2024-09-21
# 74292  74458  Text  2024-09-22
# 74293  90907  Text  2019-12-12
#
#                                                    Title Language  \
# 0      The Declaration of Independence of the United ...       en
# 1      The United States Bill of Rights\r\nThe Ten Or...       en
# 2                    John F. Kennedy's Inaugural Address       en
# 3      Lincoln's Gettysburg Address\r\nGiven November...       en
# 4                         The United States Constitution       en
# ...                                                  ...      ...
# 74289                                      La survivante       fr
# 74290         Lord Lister No. 0029: Het Indische raadsel       nl
# 74291                                   Voimakasta väkeä       fi
# 74292                                           Victoria       en
# 74293                                           No title       en
#
#                                                  Authors  \
# 0                           Jefferson, Thomas, 1743-1826
# 1                                          United States
# 2          Kennedy, John F. (John Fitzgerald), 1917-1963
# 3                            Lincoln, Abraham, 1809-1865
# 4                                          United States
# ...                                                  ...
# 74289                             Balde, Jean, 1885-1938
# 74290  Matull, Kurt, 1872-1920; Blankensee, Theo von,...
# 74291                          Malmberg, Aino, 1865-1933
# 74292  Hamsun, Knut, 1859-1952; Chater, Arthur G. [Tr...
# 74293                                                NaN
#
#                                                 Subjects      LoCC  \
# 0      United States -- History -- Revolution, 1775-1...  E201; JK
# 1      Civil rights -- United States -- Sources; Unit...    JK; KF
# 2      United States -- Foreign relations -- 1961-196...      E838
# 3      Consecration of cemeteries -- Pennsylvania -- ...      E456
# 4      United States -- Politics and government -- 17...    JK; KF
# ...                                                  ...       ...
# 74289                                                NaN       NaN
# 74290                                                NaN       NaN
# 74291                                                NaN       NaN
# 74292                                                NaN       NaN
# 74293                                                NaN       NaN
#
#                                              Bookshelves
# 0      Politics; American Revolutionary War; United S...
# 1      Politics; American Revolutionary War; United S...
# 2       Browsing: History - American; Browsing: Politics
# 3      US Civil War; Browsing: History - American; Br...
# 4      United States; Politics; American Revolutionar...
# ...                                                  ...
# 74289                                                NaN
# 74290                                                NaN
# 74291                                                NaN
# 74292                                                NaN
# 74293                                                NaN
#
# [74294 rows x 9 columns]

# %%
df["url"] = df["Text#"].apply(lambda x: "https://www.gutenberg.org/ebooks/" + str(x))
df["image_url"] = df["Text#"].apply(lambda x: "https://www.gutenberg.org/cache/epub/{}/pg{}.cover.medium.jpg".format(x, x))

# %%
df
# Out:
#        Text#  Type      Issued  \
# 0          1  Text  1971-12-01
# 1          2  Text  1972-12-01
# 2          3  Text  1973-11-01
# 3          4  Text  1973-11-01
# 4          5  Text  1975-12-01
# ...      ...   ...         ...
# 74289  74455  Text  2024-09-21
# 74290  74456  Text  2024-09-21
# 74291  74457  Text  2024-09-21
# 74292  74458  Text  2024-09-22
# 74293  90907  Text  2019-12-12
#
#                                                    Title Language  \
# 0      The Declaration of Independence of the United ...       en
# 1      The United States Bill of Rights\r\nThe Ten Or...       en
# 2                    John F. Kennedy's Inaugural Address       en
# 3      Lincoln's Gettysburg Address\r\nGiven November...       en
# 4                         The United States Constitution       en
# ...                                                  ...      ...
# 74289                                      La survivante       fr
# 74290         Lord Lister No. 0029: Het Indische raadsel       nl
# 74291                                   Voimakasta väkeä       fi
# 74292                                           Victoria       en
# 74293                                           No title       en
#
#                                                  Authors  \
# 0                           Jefferson, Thomas, 1743-1826
# 1                                          United States
# 2          Kennedy, John F. (John Fitzgerald), 1917-1963
# 3                            Lincoln, Abraham, 1809-1865
# 4                                          United States
# ...                                                  ...
# 74289                             Balde, Jean, 1885-1938
# 74290  Matull, Kurt, 1872-1920; Blankensee, Theo von,...
# 74291                          Malmberg, Aino, 1865-1933
# 74292  Hamsun, Knut, 1859-1952; Chater, Arthur G. [Tr...
# 74293                                                NaN
#
#                                                 Subjects      LoCC  \
# 0      United States -- History -- Revolution, 1775-1...  E201; JK
# 1      Civil rights -- United States -- Sources; Unit...    JK; KF
# 2      United States -- Foreign relations -- 1961-196...      E838
# 3      Consecration of cemeteries -- Pennsylvania -- ...      E456
# 4      United States -- Politics and government -- 17...    JK; KF
# ...                                                  ...       ...
# 74289                                                NaN       NaN
# 74290                                                NaN       NaN
# 74291                                                NaN       NaN
# 74292                                                NaN       NaN
# 74293                                                NaN       NaN
#
#                                              Bookshelves  \
# 0      Politics; American Revolutionary War; United S...
# 1      Politics; American Revolutionary War; United S...
# 2       Browsing: History - American; Browsing: Politics
# 3      US Civil War; Browsing: History - American; Br...
# 4      United States; Politics; American Revolutionar...
# ...                                                  ...
# 74289                                                NaN
# 74290                                                NaN
# 74291                                                NaN
# 74292                                                NaN
# 74293                                                NaN
#
#                                           url  \
# 0          https://www.gutenberg.org/ebooks/1
# 1          https://www.gutenberg.org/ebooks/2
# 2          https://www.gutenberg.org/ebooks/3
# 3          https://www.gutenberg.org/ebooks/4
# 4          https://www.gutenberg.org/ebooks/5
# ...                                       ...
# 74289  https://www.gutenberg.org/ebooks/74455
# 74290  https://www.gutenberg.org/ebooks/74456
# 74291  https://www.gutenberg.org/ebooks/74457
# 74292  https://www.gutenberg.org/ebooks/74458
# 74293  https://www.gutenberg.org/ebooks/90907
#
#                                                image_url
# 0      https://www.gutenberg.org/cache/epub/1/pg1.cov...
# 1      https://www.gutenberg.org/cache/epub/2/pg2.cov...
# 2      https://www.gutenberg.org/cache/epub/3/pg3.cov...
# 3      https://www.gutenberg.org/cache/epub/4/pg4.cov...
# 4      https://www.gutenberg.org/cache/epub/5/pg5.cov...
# ...                                                  ...
# 74289  https://www.gutenberg.org/cache/epub/74455/pg7...
# 74290  https://www.gutenberg.org/cache/epub/74456/pg7...
# 74291  https://www.gutenberg.org/cache/epub/74457/pg7...
# 74292  https://www.gutenberg.org/cache/epub/74458/pg7...
# 74293  https://www.gutenberg.org/cache/epub/90907/pg9...
#
# [74294 rows x 11 columns]

# %%
queries = [UpdateOne(
    {"Text#": record["Text#"]},
    {"$set": record},
    upsert=True
) for record in df.to_dict(orient="records")]

client["product_db"]["gutenberg"].bulk_write(queries)
# Out:
# ---------------------------------------------------------------------------
# _OperationCancelled                       Traceback (most recent call last)
# Cell In[15], line 7
#       1 queries = [UpdateOne(
#       2     {"Text#": record["Text#"]},
#       3     {"$set": record},
#       4     upsert=True
#       5 ) for record in df.to_dict(orient="records")]
# ----> 7 client["product_db"]["gutenberg"].bulk_write(queries)
#
# File ~/Desktop/Programming/Hackathons/sunhacks-2024/venv/lib/python3.10/site-packages/pymongo/_csot.py:120, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     118         with _TimeoutContext(timeout):
#     119             return func(self, *args, **kwargs)
# --> 120 return func(self, *args, **kwargs)
#
# File ~/Desktop/Programming/Hackathons/sunhacks-2024/venv/lib/python3.10/site-packages/pymongo/synchronous/collection.py:770, in Collection.bulk_write(self, requests, ordered, bypass_document_validation, session, comment, let)
#     767         raise TypeError(f"{request!r} is not a valid request") from None
#     769 write_concern = self._write_concern_for(session)
# --> 770 bulk_api_result = blk.execute(write_concern, session, _Op.INSERT)
#     771 if bulk_api_result is not None:
#     772     return BulkWriteResult(bulk_api_result, True)
#
# File ~/Desktop/Programming/Hackathons/sunhacks-2024/venv/lib/python3.10/site-packages/pymongo/synchronous/bulk.py:736, in _Bulk.execute(self, write_concern, session, operation)
#     734         return None
#     735 else:
# --> 736     return self.execute_command(generator, write_concern, session, operation)
#
# File ~/Desktop/Programming/Hackathons/sunhacks-2024/venv/lib/python3.10/site-packages/pymongo/synchronous/bulk.py:593, in _Bulk.execute_command(self, generator, write_concern, session, operation)
#     582     self._execute_command(
#     583         generator,
#     584         write_concern,
#    (...)
#     589         full_result,
#     590     )
#     592 client = self.collection.database.client
# --> 593 _ = client._retryable_write(
#     594     self.is_retryable,
#     595     retryable_bulk,
#     596     session,
#     597     operation,
#     598     bulk=self,  # type: ignore[arg-type]
#     599     operation_id=op_id,
#     600 )
#     602 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#     603     _raise_bulk_write_error(full_result)
#
# File ~/Desktop/Programming/Hackathons/sunhacks-2024/venv/lib/python3.10/site-packages/pymongo/synchronous/mongo_client.py:1898, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    1884 """Execute an operation with consecutive retries if possible
#    1885
#    1886 Returns func()'s return value on success. On error retries the same
#    (...)
#    1895 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    1896 """
#    1897 with self._tmp_session(session) as s:
# -> 1898     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File ~/Desktop/Programming/Hackathons/sunhacks-2024/venv/lib/python3.10/site-packages/pymongo/synchronous/mongo_client.py:1784, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1779 # Ensure that the options supports retry_writes and there is a valid session not in
#    1780 # transaction, otherwise, we will not support retry behavior for this txn.
#    1781 retryable = bool(
#    1782     retryable and self.options.retry_writes and session and not session.in_transaction
#    1783 )
# -> 1784 return self._retry_internal(
#    1785     func=func,
#    1786     session=session,
#    1787     bulk=bulk,
#    1788     operation=operation,
#    1789     retryable=retryable,
#    1790     operation_id=operation_id,
#    1791 )
#
# File ~/Desktop/Programming/Hackathons/sunhacks-2024/venv/lib/python3.10/site-packages/pymongo/_csot.py:120, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     118         with _TimeoutContext(timeout):
#     119             return func(self, *args, **kwargs)
# --> 120 return func(self, *args, **kwargs)
#
# File ~/Desktop/Programming/Hackathons/sunhacks-2024/venv/lib/python3.10/site-packages/pymongo/synchronous/mongo_client.py:1830, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1793 @_csot.apply
#    1794 def _retry_internal(
#    1795     self,
#    (...)
#    1804     operation_id: Optional[int] = None,
#    1805 ) -> T:
#    1806     """Internal retryable helper for all client transactions.
#    1807
#    1808     :param func: Callback function we want to retry
#    (...)
#    1817     :return: Output of the calling func()
#    1818     """
#    1819     return _ClientConnectionRetryable(
#    1820         mongo_client=self,
#    1821         func=func,
#    1822         bulk=bulk,
#    1823         operation=operation,
#    1824         is_read=is_read,
#    1825         session=session,
#    1826         read_pref=read_pref,
#    1827         address=address,
#    1828         retryable=retryable,
#    1829         operation_id=operation_id,
# -> 1830     ).run()
#
# File ~/Desktop/Programming/Hackathons/sunhacks-2024/venv/lib/python3.10/site-packages/pymongo/synchronous/mongo_client.py:2554, in _ClientConnectionRetryable.run(self)
#    2552 self._check_last_error(check_csot=True)
#    2553 try:
# -> 2554     return self._read() if self._is_read else self._write()
#    2555 except ServerSelectionTimeoutError:
#    2556     # The application may think the write was never attempted
#    2557     # if we raise ServerSelectionTimeoutError on the retry
#    2558     # attempt. Raise the original exception instead.
#    2559     self._check_last_error()
#
# File ~/Desktop/Programming/Hackathons/sunhacks-2024/venv/lib/python3.10/site-packages/pymongo/synchronous/mongo_client.py:2676, in _ClientConnectionRetryable._write(self)
#    2674             self._check_last_error()
#    2675             self._retryable = False
# -> 2676         return self._func(self._session, conn, self._retryable)  # type: ignore
#    2677 except PyMongoError as exc:
#    2678     if not self._retryable:
#
# File ~/Desktop/Programming/Hackathons/sunhacks-2024/venv/lib/python3.10/site-packages/pymongo/synchronous/bulk.py:582, in _Bulk.execute_command.<locals>.retryable_bulk(session, conn, retryable)
#     579 def retryable_bulk(
#     580     session: Optional[ClientSession], conn: Connection, retryable: bool
#     581 ) -> None:
# --> 582     self._execute_command(
#     583         generator,
#     584         write_concern,
#     585         session,
#     586         conn,
#     587         op_id,
#     588         retryable,
#     589         full_result,
#     590     )
#
# File ~/Desktop/Programming/Hackathons/sunhacks-2024/venv/lib/python3.10/site-packages/pymongo/synchronous/bulk.py:527, in _Bulk._execute_command(self, generator, write_concern, session, conn, op_id, retryable, full_result, final_write_concern)
#     525 # Run as many ops as possible in one command.
#     526 if write_concern.acknowledged:
# --> 527     result, to_send = self._execute_batch(bwc, cmd, ops, client)
#     529     # Retryable writeConcernErrors halt the execution of this run.
#     530     wce = result.get("writeConcernError", {})
#
# File ~/Desktop/Programming/Hackathons/sunhacks-2024/venv/lib/python3.10/site-packages/pymongo/synchronous/bulk.py:451, in _Bulk._execute_batch(self, bwc, cmd, ops, client)
#     449 else:
#     450     request_id, msg, to_send = bwc.batch_command(cmd, ops)
# --> 451     result = self.write_command(bwc, cmd, request_id, msg, to_send, client)  # type: ignore[arg-type]
#     453 return result, to_send
#
# File ~/Desktop/Programming/Hackathons/sunhacks-2024/venv/lib/python3.10/site-packages/pymongo/synchronous/helpers.py:45, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      42 from pymongo.synchronous.pool import Connection
#      44 try:
# ---> 45     return func(*args, **kwargs)
#      46 except OperationFailure as exc:
#      47     if no_reauth:
#
# File ~/Desktop/Programming/Hackathons/sunhacks-2024/venv/lib/python3.10/site-packages/pymongo/synchronous/bulk.py:263, in _Bulk.write_command(self, bwc, cmd, request_id, msg, docs, client)
#     261     bwc._start(cmd, request_id, docs)
#     262 try:
# --> 263     reply = bwc.conn.write_command(request_id, msg, bwc.codec)  # type: ignore[misc]
#     264     duration = datetime.datetime.now() - bwc.start_time
#     265     if _COMMAND_LOGGER.isEnabledFor(logging.DEBUG):
#
# File ~/Desktop/Programming/Hackathons/sunhacks-2024/venv/lib/python3.10/site-packages/pymongo/synchronous/pool.py:624, in Connection.write_command(self, request_id, msg, codec_options)
#     616 """Send "insert" etc. command, returning response as a dict.
#     617
#     618 Can raise ConnectionFailure or OperationFailure.
#    (...)
#     621 :param msg: bytes, the command message.
#     622 """
#     623 self.send_message(msg, 0)
# --> 624 reply = self.receive_message(request_id)
#     625 result = reply.command_response(codec_options)
#     627 # Raises NotPrimaryError or OperationFailure.
#
# File ~/Desktop/Programming/Hackathons/sunhacks-2024/venv/lib/python3.10/site-packages/pymongo/synchronous/pool.py:592, in Connection.receive_message(self, request_id)
#     590     return receive_message(self, request_id, self.max_message_size)
#     591 except BaseException as error:
# --> 592     self._raise_connection_failure(error)
#
# File ~/Desktop/Programming/Hackathons/sunhacks-2024/venv/lib/python3.10/site-packages/pymongo/synchronous/pool.py:590, in Connection.receive_message(self, request_id)
#     585 """Receive a raw BSON message or raise ConnectionFailure.
#     586
#     587 If any exception is raised, the socket is closed.
#     588 """
#     589 try:
# --> 590     return receive_message(self, request_id, self.max_message_size)
#     591 except BaseException as error:
#     592     self._raise_connection_failure(error)
#
# File ~/Desktop/Programming/Hackathons/sunhacks-2024/venv/lib/python3.10/site-packages/pymongo/synchronous/network.py:320, in receive_message(conn, request_id, max_message_size)
#     318         deadline = None
#     319 # Ignore the response's request id.
# --> 320 length, _, response_to, op_code = _UNPACK_HEADER(_receive_data_on_socket(conn, 16, deadline))
#     321 # No request_id for exhaust cursor "getMore".
#     322 if request_id is not None:
#
# File ~/Desktop/Programming/Hackathons/sunhacks-2024/venv/lib/python3.10/site-packages/pymongo/synchronous/network.py:390, in _receive_data_on_socket(conn, length, deadline)
#     388 while bytes_read < length:
#     389     try:
# --> 390         wait_for_read(conn, deadline)
#     391         # CSOT: Update timeout. When the timeout has expired perform one
#     392         # final non-blocking recv. This helps avoid spurious timeouts when
#     393         # the response is actually already buffered on the client.
#     394         if _csot.get_timeout() and deadline is not None:
#
# File ~/Desktop/Programming/Hackathons/sunhacks-2024/venv/lib/python3.10/site-packages/pymongo/synchronous/network.py:377, in wait_for_read(conn, deadline)
#     375     readable = conn.socket_checker.select(sock, read=True, timeout=timeout)
#     376 if conn.cancel_context.cancelled:
# --> 377     raise _OperationCancelled("operation cancelled")
#     378 if readable:
#     379     return
#
# _OperationCancelled: operation cancelled
